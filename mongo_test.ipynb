# %%
pip install dnspython
# Out:
# Requirement already satisfied: dnspython in c:\python39\lib\site-packages (1.16.0)Note: you may need to restart the kernel to use updated packages.

# %%
pip install pymongo[srv]
# Out:
# Requirement already satisfied: pymongo[srv] in c:\python39\lib\site-packages (3.12.0)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: dnspython<2.0.0,>=1.16.0 in c:\python39\lib\site-packages (from pymongo[srv]) (1.16.0)

# %%
import pymongo,json
 
myclient = pymongo.MongoClient("mongodb+srv://lei:user@cluster0.fi8bm.mongodb.net/myFirstDatabase?retryWrites=true&w=majority")
# mydb = myclient["music_db"]
# mycol = mydb["music"]
mydb = myclient["music_db"]
mycol = mydb["music"]
with open("file.json",encoding='UTF-8') as f:
    js_data = json.load(f)
js_data = json.loads(js_data)
mylist = []
mylist.append(js_data)
print(js_data)
x = mycol.insert_many(mylist)
print(x)
# Out:
# {'孫盛希': [['查無此曲', 'https://www.youtube.com/embed/I1tDtYNW6DM', '<dd class="fsZx3" id="fsZx3"><br/>作詞：張伍 Chang Wu、孫盛希 Shi Shi<br/>作曲：孫盛希 Shi Shi、許郁瑛 YuYing Hsu、翁光煒 Wico Weng、米奇林 MCKY、簡道生 Dawson Chien、紀冠宇 Kuan、鍾濰宇 Yu<br/>編曲：許郁瑛 YuYing Hsu、簡道生 Dawson Chien、翁光煒 Wico Weng、紀冠宇 Kuan、孫盛希 Shi Shi<br/><br/>我還能回去哪<br/>虛構的晚安 呼吸聲 電話響<br/>又在同個地方打轉<br/>榨乾我所有期盼<br/><br/>剩下合照還在那<br/>舊地多了新的傷<br/>沒差吧 這一次多深或多大<br/>交疊的傷 已成了疤<br/><br/>Woo<br/>丟了吧<br/>空了嗎<br/>更多更詳盡歌詞 在 <br/><br/>別對我失望<br/>會藏好挫敗感<br/>會振作 會放下<br/>假裝還過得不差<br/><br/>不安 不滿 在膨脹<br/>拿進 拿出 再封上<br/>慢慢的品嚐<br/>這重量沒有人共享<br/><br/>Woo<br/>懲罰<br/>我的遺憾<br/><br/>\n</dd>']], '李榮浩': [['不遺憾', 'https://www.youtube.com/embed/uQi7g4frO7o', '<dd class="fsZx3" id="fsZx3"><br/>電影 你的婚禮 主題曲<br/><br/>作詞：李榮浩<br/>作曲：王曉東@時光列車TIMEEXPRESS<br/><br/>終於看到<br/>你穿著想要的 那種婚紗<br/>你右手接過 那捧花<br/>從今後 換成他 保護你 照顧你<br/>不論貧窮富裕<br/>不論生老病疾<br/><br/>以後路上<br/>知道你會過的 有模有樣<br/>我不會中途 先退場<br/>我要等那一幕<br/>我知道我會哭<br/>更多更詳盡歌詞 在 <br/>也知道我哭是為給你祝福<br/><br/>愛